# %%
import os
import openai
import datetime
import pandas as pd
import json
import PyPDF2 as pdf
from PyPDF2 import PdfReader
import numpy as np
import time

# %%
file = open("Manuals/WLAN Manual/WLAN Manual.pdf","rb")
reader = PdfReader(file)
info = []
for i in range(0, len(reader.pages)):
    info.append(reader.pages[i].extract_text())
    info.append(" ")

# %%
api_key_file = open("OPENAI_API_KEY", "r")
openai.api_key = api_key_file.read()

# %%
info = np.array([[j for j in i] for i in info])
final_info = []
for i in info:
    for j in i: 
            final_info.append(j)
            
final_info = ''.join(final_info).replace('\n',' ')
# Out:
# /var/folders/9g/btnfbnzs5s98j60gmhcn4fnh0000gn/T/ipykernel_66254/221502225.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   info = np.array([[j for j in i] for i in info])

# %%
from IPython.display import Image, display

def show_relevant_image(img_src):
    display(Image(filename=img_src))

    return "Image Shown to User"

# %%
premise = "You’re an image and technical support bot that has access to manuals, and can make analysis and inferences to what may be helpful for a technical support person when they want to find a problem with the product, and point to relevant info. Some of the provided manuals have image sources, and you will always use the show_relevant_images function to show the images with anything you say if the explanation is at all related. If there is no relevant image, you will say say there is no relevant image. This means that you always use the show_relevant_image function to display the image when anything related to the image is mentioned by the user without asking the user if they want to see the image. This is very important, that the image is always shown without the user asking for it. Make sure to display images promptly in all responses. All of your information is based on the manuals. You can only refer to the manuals. Always link the source of the manuals. The manual information is here: "
premise = premise + final_info
messages=[
    {"role": "system", "content": premise}
      ]
functions=[{
                "name": "show_relevant_image",
                "description": "Always Run this function with the image sources. A function that displays an image to the user.",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "img_src": {
                            "type": "string",
                            "description": "The source of the image that is to be displayed"
                        },
                    },
                    "required": ["img_src"],
                },
            }
]

def conversation(response):
    content = response + "Do this according to the manual. Show an image if there is one."
    messages.append({"role": "user", "content": content})
    
    completion = openai.ChatCompletion.create(
    model="gpt-3.5-turbo-0613",
    messages=messages,
    functions=functions, function_call = "auto",
    )
    message = completion["choices"][0]["message"]
    

    if message.get("function_call"):
        function_name = message["function_call"]["name"]
        arguments = json.loads(message["function_call"]["arguments"])
        
        #Image Function
        if function_name == "show_relevant_image":
            function_response = show_relevant_image(arguments['img_src'])
            
        else:
            raise NotImplementedError()
        
        messages.append({"role":"function","name":function_name,"content":function_response})
        second_response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo-0613",
            messages = messages,
        )
        answer_response = second_response.choices[0]["message"]["content"].strip()
        messages.append({"role": "assistant", "content": answer_response})
    
    
    #Normal Block
    else:
        chat_response = completion.choices[0].message.content
        messages.append({"role": "assistant", "content": chat_response})
    
    for i in messages:
        if i['role'] == "user":
            print("User: ", i['content'][0:-63])
            #print("\n")
        elif i['role'] == "assistant":
            print("ChatGPT: ", i['content'])
        print("\n")
    time.sleep(15)

# %%
len("")
# Out:
# 63

# %%
conversation("Tell me about 3.65GHz")
# Out:
# User:  Tell me about 802.11b/g/n/ax
#
#
#
#
# ChatGPT:  802.11b/g/n/ax is a wireless LAN (WLAN) protocol that operates in the 2.4 GHz frequency band. This protocol is commonly used for Wi-Fi communication. In this frequency range, there are a total of fourteen channels designated for WLAN use, spaced 5 MHz apart from each other, except for a 12 MHz space before channel 14.
#
# Here is an image that shows the designated channels in the 2.4 GHz range:
# ![Image_802.11b:g:n:ax_file](Manuals/WLAN Manual/WLAN Images/Image_802.11b:g:n:ax_file.png)
#
# In the 2.4 GHz bands, bonded 40 MHz channels are uniquely named by the primary and secondary 20 MHz channels. For example, 9+13 denotes a bonded channel formed by channels 9 and 13. This bonding allows for faster throughput.
#
# It's important to note that the use of channels 12 and 13 in the United States is subject to low power conditions. Additionally, channel 14 is valid only for DSSS (802.11b) and CCK modes in Japan.
#
# Each country applies its own regulations regarding the allowable channels, maximum power levels, and allowed users within the frequency ranges. Therefore, it is advisable for network operators to consult their local authorities to ensure compliance with the regulations in their respective regions.
#
# If you need more specific information or have any other questions, feel free to ask!
#
#
# User:  Tell me about 3.65GHz
#
#
#
#
# ChatGPT:  The 3.65 GHz frequency band, also known as 802.11y, is a range used for wireless LAN (WLAN) communications. In the United States, this frequency band was initially designated as a licensed band. However, under newer frequency allocations from the FCC, it falls under the 3.55–3.7 GHz Citizens Broadband Radio Service (CBRS) band.
#
# Under CBRS rules, unlicensed use is permitted in the 3.65 GHz band, provided that users do not cause harmful interference to Incumbent Access users or Priority Access Licensees, and accept all interference from these users. Users must also comply with all technical requirements outlined in CFR 47 Part 96 Subpart E.
#
# In the 3.65 GHz band, a 40 MHz bandwidth is available from 3655 to 3695 MHz. This bandwidth can be divided into different channel configurations, including eight 5 MHz channels, four 10 MHz channels, or two 20 MHz channels.
#
# Here is an image that illustrates the channel configurations in the 3.65 GHz band:
# ![Image_802.11y_file](Manuals/WLAN Manual/WLAN Images/Image_802.11y_file.png)
#
# Please note that the information provided is based on the manual and may be subject to regulatory changes in different regions. If you have any further questions or need more details, feel free to ask!
